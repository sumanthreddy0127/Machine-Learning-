# %%
import bamboolib as bam 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
y=pd.read_csv(r'C:\\Quarter 1\\6020 Predictive analysis\\Module 2 Linear regression\\\Final\\car.csv')

# %%
y = y.loc[~(y['Horsepower'].isin(['?']))]
y['Horsepower'] = pd.to_numeric(y['Horsepower'], downcast='integer', errors='coerce')
y
# Out:
#       MPG  Cylinders  Displacement Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      Model Year  US Made
# 0            70        1
# 1            70        1
# 2            70        1
# 3            70        1
# 4            70        1
# ..          ...      ...
# 393          82        1
# 394          82        0
# 395          82        1
# 396          82        1
# 397          82        1
#
# [398 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split



#Split
x = y.iloc[:, range(1,8)]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)

import statsmodels.api as sm

lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     197.8
# Date:                Sat, 22 Jan 2022   Prob (F-statistic):          2.29e-109
# Time:                        21:47:14   Log-Likelihood:                -817.03
# No. Observations:                 313   AIC:                             1650.
# Df Residuals:                     305   BIC:                             1680.
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -16.9606      5.210     -3.255      0.001     -27.212      -6.709
# Cylinders       -0.3858      0.355     -1.086      0.278      -1.085       0.313
# Displacement     0.0200      0.009      2.329      0.021       0.003       0.037
# Horsepower      -0.0175      0.016     -1.124      0.262      -0.048       0.013
# Weight          -0.0066      0.001     -9.379      0.000      -0.008      -0.005
# Acceleration     0.0450      0.111      0.406      0.685      -0.173       0.263
# Model Year       0.8011      0.058     13.753      0.000       0.686       0.916
# US Made         -2.3086      0.535     -4.314      0.000      -3.361      -1.256
# ==============================================================================
# Omnibus:                       20.381   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.395
# Skew:                           0.441   Prob(JB):                     1.52e-07
# Kurtosis:                       4.276   Cond. No.                     8.57e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.57e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x=y[['US Made','Model Year','Weight','Displacement','Horsepower','Cylinders']]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)
lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     242.8
# Date:                Sat, 22 Jan 2022   Prob (F-statistic):          3.59e-113
# Time:                        21:46:32   Log-Likelihood:                -822.39
# No. Observations:                 313   AIC:                             1659.
# Df Residuals:                     306   BIC:                             1685.
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -15.4876      4.674     -3.313      0.001     -24.685      -6.290
# US Made         -2.8577      0.552     -5.175      0.000      -3.944      -1.771
# Model Year       0.8165      0.058     14.086      0.000       0.702       0.931
# Weight          -0.0072      0.001    -11.180      0.000      -0.008      -0.006
# Displacement     0.0272      0.009      3.114      0.002       0.010       0.044
# Horsepower      -0.0228      0.012     -1.838      0.067      -0.047       0.002
# Cylinders       -0.4854      0.358     -1.357      0.176      -1.189       0.219
# ==============================================================================
# Omnibus:                       14.682   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               20.628
# Skew:                           0.357   Prob(JB):                     3.32e-05
# Kurtosis:                       4.036   Cond. No.                     7.59e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.59e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x=y[['US Made','Model Year','Weight','Displacement','Horsepower']]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)
lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())x
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.813
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     267.7
# Date:                Sat, 22 Jan 2022   Prob (F-statistic):          1.27e-109
# Time:                        21:41:56   Log-Likelihood:                -823.14
# No. Observations:                 313   AIC:                             1658.
# Df Residuals:                     307   BIC:                             1681.
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -13.7282      4.689     -2.928      0.004     -22.954      -4.502
# US Made         -2.9421      0.547     -5.378      0.000      -4.019      -1.866
# Model Year       0.7585      0.059     12.864      0.000       0.642       0.874
# Weight          -0.0063      0.001     -9.805      0.000      -0.008      -0.005
# Displacement     0.0156      0.007      2.339      0.020       0.002       0.029
# Horsepower      -0.0273      0.012     -2.224      0.027      -0.052      -0.003
# ==============================================================================
# Omnibus:                       22.224   Durbin-Watson:                   2.044
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.250
# Skew:                           0.466   Prob(JB):                     2.22e-08
# Kurtosis:                       4.354   Cond. No.                     7.52e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.52e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x=y[['US Made','Model Year','Weight','Displacement']]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)
lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     366.0
# Date:                Sat, 22 Jan 2022   Prob (F-statistic):          1.19e-115
# Time:                        21:42:32   Log-Likelihood:                -817.10
# No. Observations:                 313   AIC:                             1644.
# Df Residuals:                     308   BIC:                             1663.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -20.3373      4.481     -4.538      0.000     -29.155     -11.520
# US Made         -2.4820      0.522     -4.755      0.000      -3.509      -1.455
# Model Year       0.8442      0.057     14.900      0.000       0.733       0.956
# Weight          -0.0071      0.001    -10.941      0.000      -0.008      -0.006
# Displacement     0.0126      0.006      2.117      0.035       0.001       0.024
# ==============================================================================
# Omnibus:                       14.733   Durbin-Watson:                   1.845
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.309
# Skew:                           0.347   Prob(JB):                     2.36e-05
# Kurtosis:                       4.074   Cond. No.                     7.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x=y[['US Made','Model Year','Weight']]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)
lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     450.5
# Date:                Sat, 22 Jan 2022   Prob (F-statistic):          1.86e-112
# Time:                        21:42:59   Log-Likelihood:                -815.90
# No. Observations:                 313   AIC:                             1640.
# Df Residuals:                     309   BIC:                             1655.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -15.2291      4.440     -3.430      0.001     -23.966      -6.492
# US Made       -1.7135      0.480     -3.568      0.000      -2.659      -0.768
# Model Year     0.7514      0.055     13.739      0.000       0.644       0.859
# Weight        -0.0059      0.000    -20.672      0.000      -0.006      -0.005
# ==============================================================================
# Omnibus:                       18.565   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.250
# Skew:                           0.437   Prob(JB):                     1.99e-06
# Kurtosis:                       4.118   Cond. No.                     7.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x=y[['US Made','Model Year']]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)
lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.584
# Model:                            OLS   Adj. R-squared:                  0.581
# Method:                 Least Squares   F-statistic:                     217.4
# Date:                Sat, 22 Jan 2022   Prob (F-statistic):           9.71e-60
# Time:                        21:43:17   Log-Likelihood:                -951.94
# No. Observations:                 313   AIC:                             1910.
# Df Residuals:                     310   BIC:                             1921.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -55.5891      6.024     -9.228      0.000     -67.442     -43.736
# US Made       -8.0083      0.600    -13.352      0.000      -9.188      -6.828
# Model Year     1.1066      0.078     14.132      0.000       0.953       1.261
# ==============================================================================
# Omnibus:                        8.826   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.876
# Skew:                           0.409   Prob(JB):                       0.0118
# Kurtosis:                       3.108   Cond. No.                     1.60e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x=y[['US Made']]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)
lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     141.9
# Date:                Sat, 22 Jan 2022   Prob (F-statistic):           3.36e-27
# Time:                        21:44:13   Log-Likelihood:                -1032.8
# No. Observations:                 313   AIC:                             2070.
# Df Residuals:                     311   BIC:                             2077.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.3145      0.608     48.201      0.000      28.118      30.511
# US Made       -9.1538      0.769    -11.911      0.000     -10.666      -7.642
# ==============================================================================
# Omnibus:                       18.647   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.905
# Skew:                           0.626   Prob(JB):                     2.89e-05
# Kurtosis:                       2.817   Cond. No.                         3.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x=y[['Model Year']]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)
lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     151.8
# Date:                Sat, 22 Jan 2022   Prob (F-statistic):           1.13e-28
# Time:                        22:37:25   Log-Likelihood:                -1026.0
# No. Observations:                 313   AIC:                             2056.
# Df Residuals:                     311   BIC:                             2063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -69.9891      7.584     -9.228      0.000     -84.912     -55.066
# Model Year     1.2297      0.100     12.320      0.000       1.033       1.426
# ==============================================================================
# Omnibus:                       16.591   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               14.281
# Skew:                           0.447   Prob(JB):                     0.000792
# Kurtosis:                       2.455   Cond. No.                     1.58e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x=y[['Weight']]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)
lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.672
# Method:                 Least Squares   F-statistic:                     640.3
# Date:                Sat, 22 Jan 2022   Prob (F-statistic):           1.72e-77
# Time:                        22:37:28   Log-Likelihood:                -914.02
# No. Observations:                 313   AIC:                             1832.
# Df Residuals:                     311   BIC:                             1840.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         46.4525      0.939     49.472      0.000      44.605      48.300
# Weight        -0.0077      0.000    -25.304      0.000      -0.008      -0.007
# ==============================================================================
# Omnibus:                       34.664   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.340
# Skew:                           0.745   Prob(JB):                     3.19e-11
# Kurtosis:                       4.218   Cond. No.                     1.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# Feature extraction
test = SelectKBest(score_func=chi2, k=5)
x=y[['US Made','Model Year','Weight','Displacement','Horsepower','Cylinders','Acceleration']]
z=z.astype('int')
fit = test.fit(x, z)

# Summarize scores
np.set_printoptions(precision=1)
print(fit.scores_)

features = fit.transform(x)
# Summarize selected features
print(features[0:5,:])
#get_feature_names_out(input_features=None)
#print(features.get_feature_names())
mask = test.get_support() #list of booleans
new_features = [] # The list of your K best features

for bool, feature in zip(mask,['US Made','Model Year','Weight','Displacement','Horsepower','Cylinders','Acceleration']):
    if bool:
        new_features.append(feature)
        
print(new_features)
# Out:
# [5.7e+01 2.7e+01 7.9e+04 1.8e+04 4.3e+03 1.6e+02 6.1e+01]
# [[3504.   307.   130.     8.    12. ]
#  [3693.   350.   165.     8.    11.5]
#  [3436.   318.   150.     8.    11. ]
#  [3433.   304.   150.     8.    12. ]
#  [3449.   302.   140.     8.    10.5]]
# ['Weight', 'Displacement', 'Horsepower', 'Cylinders', 'Acceleration']

# %%
x=y[['Weight', 'Displacement', 'Horsepower','Cylinders']]
z = y[['MPG']]

x_train, x_test, z_train, z_test = train_test_split(x, z, test_size=0.20)
lr = sm.add_constant(x_train) 
lr_model = sm.OLS(z_train, lr) 
lr_fit = lr_model.fit()
print(lr_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MPG   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     195.2
# Date:                Sun, 23 Jan 2022   Prob (F-statistic):           3.86e-83
# Time:                        18:36:45   Log-Likelihood:                -882.25
# No. Observations:                 313   AIC:                             1774.
# Df Residuals:                     308   BIC:                             1793.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           46.2376      1.587     29.135      0.000      43.115      49.360
# Weight          -0.0054      0.001     -7.219      0.000      -0.007      -0.004
# Displacement     0.0069      0.009      0.755      0.451      -0.011       0.025
# Horsepower      -0.0417      0.014     -3.062      0.002      -0.068      -0.015
# Cylinders       -0.7215      0.427     -1.691      0.092      -1.561       0.118
# ==============================================================================
# Omnibus:                       25.168   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.142
# Skew:                           0.611   Prob(JB):                     1.05e-07
# Kurtosis:                       3.986   Cond. No.                     2.19e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.19e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
